# %% [markdown]
# # Exploratory Data Analysis - Terrorism

# %% [markdown]
# Name: Shebin Benny
#
# Data Science Intern

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# reading the csv file

# %%
df=pd.read_csv('globalterrorismdb_0718dist.csv',encoding='latin1',low_memory=False)

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
#Statistical Description of the dataset
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
#To find the dimension of our dataset
df.shape
# Out:
# (181691, 135)

# %%
#To know the various attributes in our dataset
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
#renaming columns for understanding and easier reuse
df.rename(columns=({'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','motive':'Motive'}),inplace=True)

# %%
# Choosing only the important columns
df=df[['Year','Month','Day','Country','state','Region','city','latitude','longitude','AttackType','Killed','Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]
df.head()
# Out:
#    Year  Month  Day             Country    state                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             city   latitude   longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
#To display the null values for each attribute in our dataset
df.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# state             421
# Region              0
# city              434
# latitude         4556
# longitude        4557
# AttackType          0
# Killed          10313
# Wounded         16311
# Target            636
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# dtype: int64

# %%
#To find what type of datatype each column have
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   state        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   city         181257 non-null  object
#  7   latitude     177135 non-null  float64
#  8   longitude    177134 non-null  float64
#  9   AttackType   181691 non-null  object
#  10  Killed       171378 non-null  float64
#  11  Wounded      165380 non-null  float64
#  12  Target       181055 non-null  object
#  13  Summary      115562 non-null  object
#  14  Group        181691 non-null  object
#  15  Target_type  181691 non-null  object
#  16  Weapon_type  181691 non-null  object
#  17  Motive       50561 non-null   object
# ...

# %% [markdown]
# Visualizations

# %%
# To display increasing number of terror activities per year
x_year = df['Year'].unique()
y_count_years = df['Year'].value_counts().sort_index()
plt.figure(figsize = (20,10))
sns.barplot(x = x_year,
           y = y_count_years)
plt.xticks(rotation = 45)
plt.xlabel('Attack Year')
plt.ylabel('Number of Attacks each year')
plt.title('Attack Vs Years')
plt.show()

# %%
#Bar Plot - Top 15 countries that are affected
plt.figure(figsize=(10,6))
sns.barplot(df['Country'].value_counts()[:15].index,df['Country'].value_counts()[:15].values,palette='rocket')
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()
# Out:
# D:\Shebin\Anaconda\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Number of people killed in a terror attack
killData = df.loc[:,'Killed']
print('Number of people killed by terror attack:', int(sum(killData.dropna())))
# Out:
# Number of people killed by terror attack: 411868

# %%
#Country wise Death
countryData = df.loc[:,'Country']
countryKillData = pd.concat([countryData, killData], axis=1)
countryKillData
# Out:
#                    Country  Killed
# 0       Dominican Republic     1.0
# 1                   Mexico     0.0
# 2              Philippines     1.0
# 3                   Greece     NaN
# 4                    Japan     NaN
# ...                    ...     ...
# 181686             Somalia     1.0
# 181687               Syria     2.0
# 181688         Philippines     0.0
# 181689               India     0.0
# 181690         Philippines     0.0
#
# [181691 rows x 2 columns]

# %%
#Country wise Death
countryKillFormatData = countryKillData.pivot_table(columns='Country', values='Killed', aggfunc='sum')
countryKillFormatData
# Out:
# Country  Afghanistan  Albania  Algeria  Andorra  Angola  Antigua and Barbuda  \
# Killed       39384.0     42.0  11066.0      0.0  3043.0                  0.0
#
# Country  Argentina  Armenia  Australia  Austria  ...  Vietnam  \
# Killed       490.0     37.0       23.0     30.0  ...      1.0
#
# Country  Wallis and Futuna  West Bank and Gaza Strip  West Germany (FRG)  \
# Killed                 0.0                    1500.0                97.0
#
# Country  Western Sahara   Yemen  Yugoslavia  Zaire  Zambia  Zimbabwe
# Killed              1.0  8776.0       119.0  324.0    70.0     154.0
#
# [1 rows x 205 columns]

# %%
#Bar Plot - Weapon types used in attacks
plt.figure(figsize=(15, 9))
sns.barplot(
    df["Weapon_type"].value_counts()[:10].index,
    df["Weapon_type"].value_counts()[:10].values,
    palette=("rocket"),
)
plt.title("Weapon types used in attacks")
plt.xlabel("Weapon of choice")
plt.ylabel("Counts")
plt.xticks(rotation=30)
plt.show();
# Out:
# D:\Shebin\Anaconda\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15, 9))
sns.barplot(
    df["Target_type"].value_counts()[:10].index,
    df["Target_type"].value_counts()[:10].values,
    palette=("Blues_d"),
)
plt.title("Target types affected by attacks")
plt.xlabel("Target")
plt.ylabel("Counts")
plt.xticks(rotation=90)
plt.show();
# Out:
# D:\Shebin\Anaconda\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Conclusions

# %% [markdown]
# (i) By Analysing the Attacks and the years it happened, We concluded that 2014 is the year having maximum number of attacks reported
#
# (ii) From the second graph, We got a conclusion that IRAQ is the country affected with maximum number of terrorist atacks.
#
# (iii) Number of people killed by terror attack: 411868
#
# (iv) Afghanistan is the country which has leading number of deaths.
#
# (v) Explosives' were the most popular weapon among the terrorist groups for carrying out the attacks in most of the places.
#
# (vi) Terrorist attacks mostly targeted private Citizens and properties, but attacks towards military and police etc. were not less
